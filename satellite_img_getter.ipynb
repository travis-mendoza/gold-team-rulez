# %% [markdown]
# # Collect data

# %% [markdown]
# Indexes we want:
#
# *   NDVI
# *   GCI
# *   NDWI

# %% [markdown]
# ## Clean data folder

# %%
# DANGER ZONE 2

# !rm -rf spaceapps-raw

# %% [markdown]
# ## Install and import statements

# %%
import requests
import json
from pprint import pprint
import os
from datetime import datetime
import re
from tqdm import tqdm

# %% [markdown]
# ## Generate authorization token

# %%
# Get authorization token

# EarthData AppEEARS credentials
username = "token_american"
password = "AerVJ&5CL8&8PP_"

# Request token
response = requests.post('https://appeears.earthdatacloud.nasa.gov/api/login', auth=(username, password))
token_response = response.json()
pprint(token_response)

# Store token
token = token_response["token"]
# Out:
# {'expiration': '2024-10-07T20:37:04Z',
#  'token': 'N5gXbdnzl0aSzyhoZgoYVHwogxkH2y-zEbagG49fTRYf_GqkdZV0-M7XGoOhuu-7mUG-NJ-fKLhaRbUKsNULAQ',
#  'token_type': 'Bearer'}

# %% [markdown]
# ## Create Region Of Interest (ROI)

# %%
# Define the area of interest using a polygon (GeoJSON format)

polygon = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {},
            "geometry": {
                "type": "Polygon",
                "coordinates": [
                    [
                       
                        [-121.3765, 36.8772],
                        [-121.3768, 36.8723],
                        [-121.3728, 36.8721],
                        [-121.3726, 36.8760],
                        [-121.3765, 36.8772]
                        
                        
                    ]
                ]
            }
        }
    ]
}

# %% [markdown]
# ## Useful information about how to make requests

# %%
# # See all the different products that are possible to request
# response = requests.get('https://appeears.earthdatacloud.nasa.gov/api/product')
# product_response = response.json()

# # Create a dictionary indexed by the product name and version
# products = {p['ProductAndVersion']: p for p in product_response}

# # Filter the dictionary for keys that start with 'L'
# filtered_products = {k: v for k, v in products.items() if 'landsat' in v.get("Description", "").lower()}

# pprint(filtered_products)

# %%
# Check layers associated with the product

# product_id = 'L09.002'
# response = requests.get('https://appeears.earthdatacloud.nasa.gov/api/product/{0}'.format(product_id))
# layer_response = response.json()
# pprint(layer_response)

# %% [markdown]
# ### Notes about Layers
#
# * The QA_PIXEL layer would allow us to filter out bad pixels. Maybe we wouldn't need to filter out the images over the cloud cover threshold.
#
# * Likewise, the QA_RADSAT layer flags pixels that are radiometrically saturated, which means they've reached the sensor's detectable limit.
#
# * LandSAT 8 and 9 have temporal granularity of 16 days.

# %% [markdown]
# ## Download data

# %% [markdown]
# ### Create request

# %%
# Define the AppEEARS request

# Give start and end dates in MM-DD-YYYY
start_date = "10-31-2021"  # First available date for Landsat 9 imagery
end_date = "10-05-2024"

request_payload = {
    "task_type": "area",
    "task_name": "California_Field",
    "params": {
        # The last layers dictionary must not have a comma at the end
         "layers": [
            {"product": "L09.002", "layer": "SR_B2"},  # Blue band for raster plot of visible light
            {"product": "L09.002", "layer": "SR_B3"},  # Green band for NDWI and GCI
            {"product": "L09.002", "layer": "SR_B4"},  # Red band for NDVI, GCI
            {"product": "L09.002", "layer": "SR_B5"}  # NIR band for NDVI, GCI, NDWI
            # {"product": "L09.002", "layer": "SR_B6"},  # SWIR1 band for NDWI
            # {"product": "L09.002", "layer": "SR_B7"}  # SWIR2 band
         ],
        "dates": [{"startDate": start_date, "endDate": end_date}],
        "output": {"format": {"type": "geotiff"}, "projection": "geographic"},
        "geo": polygon,
        "cloud_cover": {"max": 30}  # Filter out images with more than 30% cloud cover
    }
}

# %% [markdown]
# ### AppEEARS API Tasking

# %%
# Submit the task request

response = requests.post(
    'https://appeears.earthdatacloud.nasa.gov/api/task',
    json=request_payload,
    headers={'Authorization': 'Bearer {0}'.format(token)})
task_response = response.json()
print(task_response)

task_id = task_response["task_id"]
# Out:
# {'task_id': 'c707f90a-dc7b-44f8-a0ae-024c8f9c0797', 'status': 'pending'}

# %%
def delete_task(token, task_id):
  response = requests.delete(
    'https://appeears.earthdatacloud.nasa.gov/api/task/{0}'.format(task_id),
    headers={'Authorization': 'Bearer {0}'.format(token)})
  print(response.status_code)

# %%
# Checking task status

# # Checking status for all tasks assigned to our user
# response = requests.get(
#     'https://appeears.earthdatacloud.nasa.gov/api/status/',
#     headers={'Authorization': 'Bearer {0}'.format(token)})
# status_response = response.json()
# pprint(status_response)

# task_id = 'b9fcd494-cd4d-47e1-9191-bca101f0be6c'

# # Checking status for specific task
response = requests.get(
    'https://appeears.earthdatacloud.nasa.gov/api/status/{0}'.format(task_id),
    headers={'Authorization': 'Bearer {0}'.format(token)})
status_response = response.json()
pprint(status_response)
# Out:
# {'has_swath': False,
#  'progress': {'details': [{'desc': 'Initializing',
#                            'pct_complete': 100,
#                            'step': 1},
#                           {'desc': 'Downloading',
#                            'pct_complete': 100,
#                            'step': 2},
#                           {'desc': 'Subsetting',
#                            'pct_complete': 100,
#                            'step': 3},
#                           {'desc': 'Generating Files',
#                            'pct_complete': 33,
#                            'step': 4},
#                           {'desc': 'Extracting Stats',
#                            'pct_complete': 0,
#                            'step': 5},
#                           {'desc': 'Finalizing', 'pct_complete': 0, 'step': 6}],
#               'summary': 58,
#               'user_consider_limit': False},
#  'status_id': '5e1efd57-befb-4ba5-818c-ec3a2d7aa266',
#  'status_type': 'task',
#  'task_id': 'c707f90a-dc7b-44f8-a0ae-024c8f9c0797',
#  'updated': '2024-10-06T16:41:32.060371',
#  'user_id': 'travmendoz@gmail.com'}

# %%
# DANGER ZONE

# delete_task(token, '76e76e65-5753-4e00-a8a1-04555a47d182')

# %% [markdown]
# ### Fetch & Format Files

# %%
# Retrieve files

response = requests.get(
    'https://appeears.earthdatacloud.nasa.gov/api/bundle/{0}'.format(task_id),
    headers={'Authorization': 'Bearer {0}'.format(token)}
)
files_response = response.json()

# files_response has other data types included
pprint(files_response["files"][0:2])
# Out:
# [{'file_id': '966af9eb-cb1c-4e1b-8fc0-2850d53447e7',
#   'file_name': 'L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021320_aid0001.tif',
#   'file_size': 2012,
#   'file_type': 'tif',
#   's3_url': 's3://appeears-output/b9fcd494-cd4d-47e1-9191-bca101f0be6c/L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021320_aid0001.tif',
#   'sha256': 'e74818ca627da3b09bc3666e3dbf9e7808ba8caceef69a4b86ba224fe4e79a72'},
#  {'file_id': '209e953f-4d31-42c6-9773-7371c3db69a1',
#   'file_name': 'L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021325_aid0001.tif',
#   'file_size': 1913,
#   'file_type': 'tif',
#   's3_url': 's3://appeears-output/b9fcd494-cd4d-47e1-9191-bca101f0be6c/L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021325_aid0001.tif',
#   'sha256': '6b249d1957dca19c33ed97a8b06654b51fd0acd5fecba5f23e4a25f883a9a23b'}]

# %%
# # Select A FEW FILES to work with

# file_ids = [
#     'b85bc5ac-d8fb-48eb-a600-a143d55c1399',  # B2
#     'aeb0ae27-62ad-4fcb-9f45-4e2321cd9eb8',  # B3
#     'bf2ed48c-6151-4cac-9962-2c40f25906f0'  # B4
#     ]

# # # we are intentionally using 3 files only for now
# # for f in range(0, 3):
# #   file_ids.append(files_response["files"][f]["file_id"])

# pprint(file_ids)

# for file_id in file_ids:
#   filename = file_id + '.tif'
#   response = requests.get(
#       'https://appeears.earthdatacloud.nasa.gov/api/bundle/{0}/{1}'.format(task_id,file_id),
#       headers={'Authorization': 'Bearer {0}'.format(token)},
#       allow_redirects=True,
#       stream=True
#   )

#   # Create the filepath if it doesn't exist
#   filepath = os.path.join(dest_dir, filename)
#   os.makedirs(os.path.dirname(filepath), exist_ok=True)

#   # write the file to the destination directory
#   with open(filepath, 'wb') as f:
#       for data in response.iter_content(chunk_size=8192):
#           f.write(data)

# %%
# Check if filename contains required patterns

def is_valid_filename(file_name):
    # Check for 'doy' pattern
    doy_match = re.search(r'doy\d+_', file_name)
    # Check for '_B#_' pattern
    band_match = re.search(r'_B\d+_', file_name)
    return bool(doy_match and band_match)

# %%
# Format filename
def format_fname(file_name):
  if not is_valid_filename(file_name):
    raise ValueError(
        f"Could not format filename because it is invalid: {file_name}"
        )

  doy_match = re.search(r'doy\d+_', file_name)
  doy_string = doy_match.group(0).strip('_')

  band_match = re.search(r'_B\d+_', file_name)
  band_string = band_match.group(0).strip('_')

  return f"{doy_string}_{band_string}.tif"

# %%
def download_file(file, dest_dir, token, task_id):
  filename = format_fname(file["file_name"])
  response = requests.get(
      'https://appeears.earthdatacloud.nasa.gov/api/bundle/{0}/{1}'.format(task_id, file["file_id"]),
      headers={'Authorization': 'Bearer {0}'.format(token)},
      allow_redirects=True,
      stream=True
  )

  filepath = os.path.join(dest_dir, filename)
  os.makedirs(os.path.dirname(filepath), exist_ok=True)

  # write the file to the destination directory
  with open(filepath, 'wb') as f:
      for data in response.iter_content(chunk_size=8192):
          f.write(data)

# %%
# Download files

# Create directory where files will be stored
base_dir = "spaceapps-raw"

# Get the current date and time
current_time = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

# Create a subdirectory with the date and time
dest_dir = os.path.join(base_dir, current_time)

# Create the directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)

skipped_files = []
# Download each file
for file in tqdm(
    files_response["files"],
    desc="Downloading image files",
    unit="file"
    ):
  if is_valid_filename(file["file_name"]):
    download_file(file, dest_dir, token, task_id)
  else:
    skipped_files.append(f"{file['file_name']}")

if skipped_files:
  print("\n\nSkipped these files on account of their names:")
  print("\n".join(skipped_files))
# Out:
# Downloading image files: 100%|██████████| 916/916 [09:59<00:00,  1.53file/s]
# Skipped these files on account of their names:
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021320_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021325_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021337_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021344_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021353_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2021360_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022004_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022011_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022020_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022027_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022036_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022043_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022052_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022059_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022068_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022084_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022091_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022100_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022107_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022116_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022123_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022132_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022139_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022148_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022155_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022164_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022171_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022180_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022187_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022196_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022203_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022212_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022219_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022228_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022235_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022244_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022251_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022260_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022267_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022276_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022283_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022292_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022299_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022308_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022315_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022324_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022331_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022340_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022347_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022356_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2022363_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2023007_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2023014_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2023023_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2023030_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2023039_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2023046_aid0001.tif
# L09.002_2021289_to_2024279/L09.002_SR_QA_AEROSOL_CU_doy2
B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022276_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023327_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022203_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024010_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023103_B3.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023359_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023247_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023334_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022276_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022347_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023334_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023302_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021344_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022235_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024042_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023078_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022196_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024058_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022260_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022148_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024273_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024122_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024257_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022036_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023343_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021320_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023046_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024065_B3.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022164_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022292_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022251_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024138_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021320_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022116_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023110_B3.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023014_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023327_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024081_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024026_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024097_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022283_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023007_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023174_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022155_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023110_B4.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023311_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023247_B3.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021320_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022203_B4.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022324_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023238_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023318_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022171_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023142_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023199_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024186_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023190_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022027_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023142_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023151_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022084_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023094_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022308_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022068_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023183_B4.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023158_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022315_B3.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024065_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022180_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024033_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023071_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023062_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024081_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023190_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023007_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022132_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022148_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021353_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024209_B3.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021325_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023270_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021337_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023286_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023167_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023270_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023295_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023183_B3.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024081_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023295_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022100_B4.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022340_B5.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023071_B5.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024170_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022283_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023174_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023110_B5.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024042_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022123_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024138_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022052_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024234_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022212_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024250_B3.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024241_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023167_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023087_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022036_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023062_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024241_B3.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022020_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022292_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022068_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023126_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022331_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023039_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022059_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024122_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024225_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023343_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022267_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021325_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023158_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022235_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024113_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024113_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023135_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022187_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022100_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022347_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023078_B4.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024001_B3.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024154_B3.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022244_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022171_B3.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023206_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023014_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023318_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024049_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023206_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023343_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024225_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024049_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023023_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024049_B4.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022276_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024193_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022036_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023055_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022004_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2021353_B3.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022139_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024161_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023190_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024161_B5.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022059_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024065_B4.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023094_B5.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024017_B4.tif (deflated 8%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024266_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024177_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024145_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023087_B4.tif (deflated 11%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023046_B3.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2024209_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022219_B4.tif (deflated 9%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2022091_B5.tif (deflated 10%)
#   adding: spaceapps-raw/2024-10-06_13-49-16/doy2023222_B4.tif (deflated 8%)

# %%
# # Download the README and Statistics files

# meta_file_idxs = [-1, -5]

# meta_file_ids = [
#     files_response["files"][meta_file_idxs[0]]["file_id"],
#     files_response["files"][meta_file_idxs[1]]["file_id"]
# ]

# meta_fns = [
#     files_response["files"][meta_file_idxs[0]]["file_name"],
#     files_response["files"][meta_file_idxs[1]]["file_name"]
#     ]

# pprint(meta_fns)

# for i, fid in enumerate(meta_file_ids):
#   print(i, fid)
#   response = requests.get(
#       'https://appeears.earthdatacloud.nasa.gov/api/bundle/{0}/{1}'.format(task_id, fid),
#       headers={'Authorization': 'Bearer {0}'.format(token)},
#       allow_redirects = True,
#       stream=True
#   )

#   # Create the filepath if it doesn't exist
#   filename = meta_fns[i]
#   filepath = os.path.join(dest_dir, filename)
#   os.makedirs(os.path.dirname(filepath), exist_ok=True)

#   # write the file to the destination directory
#   with open(filepath, 'wb') as f:
#       for data in response.iter_content(chunk_size=8192):
#           f.write(data)

# %% [markdown]
# # Analyze data

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.8.30)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.1.4)

# %%
# import earthpy as et
# import earthpy.spatial as es
# import earthpy.plot as ep
import rasterio as rio
import matplotlib.pyplot as plt
import numpy as np
# from matplotlib.colors import ListedColormap
# import plotly.graph_objects as go

# %%
# Plot visual spectrum as a data quality check

# Consider the reflectance scale factor from layer metadata
scale_factor = 2.75e-05

# Open the GeoTIFF files for each band
with rio.open('/content/spaceapps-raw/b85bc5ac-d8fb-48eb-a600-a143d55c1399.tif') as blue_band, \
     rio.open('/content/spaceapps-raw/aeb0ae27-62ad-4fcb-9f45-4e2321cd9eb8.tif') as green_band, \
     rio.open('/content/spaceapps-raw/bf2ed48c-6151-4cac-9962-2c40f25906f0.tif') as red_band:

    # Read each band
    blue = blue_band.read(1).astype('float32') * scale_factor
    green = green_band.read(1).astype('float32') * scale_factor
    red = red_band.read(1).astype('float32') * scale_factor

    # Stack bands into an RGB image (Red, Green, Blue)
    rgb_image = np.dstack((red, green, blue))

    # Plot the RGB image using matplotlib
    plt.figure(figsize=(10, 10))
    plt.imshow(rgb_image)
    plt.title("RGB Composite of SR_B2 (Blue), SR_B3 (Green), SR_B4 (Red)")
    plt.axis('off')  # Hide axis for better visual representation
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_base.pyx in rasterio._base.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: './spaceapps-raw/b85bc5ac-d8fb-48eb-a600-a143d55c1399.tif' not recognized as being in a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-38-09bfe3af1ca4> in <cell line: 7>()
#       5
#       6 # Open the GeoTIFF files for each band
# ----> 7 with rio.open('./spaceapps-raw/b85bc5ac-d8fb-48eb-a600-a143d55c1399.tif') as blue_band, \
#       8      rio.open('./spaceapps-raw/aeb0ae27-62ad-4fcb-9f45-4e2321cd9eb8.tif') as green_band, \
#       9      rio.open('./spaceapps-raw/bf2ed48c-6151-4cac-9962-2c40f25906f0.tif') as red_band:
#
# /usr/local/lib/python3.10/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     461
#     462         with env_ctor(session=session):
# --> 463             return f(*args, **kwds)
#     464
#     465     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353
#     354             if mode == "r":
# --> 355                 dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     356             elif mode == "r+":
#     357                 dataset = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: './spaceapps-raw/b85bc5ac-d8fb-48eb-a600-a143d55c1399.tif' not recognized as being in a supported file format.

# %%
# prompt: Calculate NDVI

with rio.open('/content/spaceapps-raw/bf2ed48c-6151-4cac-9962-2c40f25906f0.tif') as red_band, \
     rio.open('/content/spaceapps-raw/aeb0ae27-62ad-4fcb-9f45-4e2321cd9eb8.tif') as nir_band:

    # Read each band
    red = red_band.read(1).astype('float32') * scale_factor
    nir = nir_band.read(1).astype('float32') * scale_factor

    # Calculate NDVI
    ndvi = (nir - red) / (nir + red)

    # Plot NDVI
    plt.figure(figsize=(10, 10))
    plt.imshow(ndvi, cmap='RdYlGn')
    plt.colorbar(label='NDVI')
    plt.title('Normalized Difference Vegetation Index (NDVI)')
    plt.axis('off')
    plt.show()

# %%
# prompt: calculate GCI

with rio.open('/content/spaceapps-raw/aeb0ae27-62ad-4fcb-9f45-4e2321cd9eb8.tif') as green_band, \
     rio.open('/content/spaceapps-raw/bf2ed48c-6151-4cac-9962-2c40f25906f0.tif') as red_band:

    # Read each band
    green = green_band.read(1).astype('float32') * scale_factor
    red = red_band.read(1).astype('float32') * scale_factor

    # Calculate GCI
    gci = (nir / green) - 1

    # Plot GCI
    plt.figure(figsize=(10, 10))
    plt.imshow(gci, cmap='RdYlGn')
    plt.colorbar(label='GCI')
    plt.title('Green Chlorophyll Index (GCI)')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # What should we do now?
#
# 1. Label 100 images
#   - date_color.tif
# 1. Rotate image
# 1. Add computations for 3 indexes
# 1. Load more data..? Let's do 2 years for now.
# 1. Add data processing.
#
# ## Manny's Plan
#
# ```
# for each image:
# 1. Compute the mean NDVI, GCI and Water Index
# 2.
#
# ```
